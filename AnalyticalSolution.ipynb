# %% [markdown]
# ### Analytical Solution

# %% [markdown]
# For the CARA Utility function:
# $$
# U(W_{T})=\frac{1-e^{-\alpha W_{T}}}{\alpha}, \alpha\neq 0
# $$
# Since we as assume no consumption of wealth from $t = 0,1,...,T-1$
# We can smplified the MDP reward at time $T$ as
# $$
# \frac{-e^{-\alpha W_{T}}}{\alpha}
# $$
# So we can denote the Value function at time t given policy $\pi$ as:
# $$
# V^{\pi}_{t}(W_{t})=\mathbb{E}_{\pi}[\frac{-e^{-\alpha W_{T}}}{\alpha}|(t,W_{t})]
# $$
# and the Bellman Optimality Equation is:
# $$
# V^{*}_{t}(W_{t}) = \max_{{x_t}}Q^{*}_{t}(W_{t},x_t)=\max_{{x_t}}\mathbb{E}_{Y_t}[V^{*}_{t+1}(W_{t+1})]
# $$
# for $t=0,1,...,T-2$, and
# $$
# V^{*}_{T-1}(W_{T-1}) = \max_{{x_{T-1}}}Q^{*}_{T-1}(W_{T-1},x_{T-1})=\max_{{{x_{T-1}}}}\mathbb{E}_{Y_{T-1}}[\frac{-e^{-\alpha W_{T}}}{\alpha}]
# $$
# for $t=T-1$
# Using an educated guess of the functional form of Optimal Value Function:
# $$
# V^{*}_{t}(W_{t})=-b_te^{c_tW_t}
# $$

# %% [markdown]
# So, the Bellman Optimality Equation can be writtten as
# $$V^{*}_{t}(W_{t})=\max_{{x_t}}\mathbb{E}_{Y_t}[-b_{t+1}e^{c_{t+1}W_{t+1}}]\\
# =\max_{{x_t}}\{\mathbb{E}_{Y_{t}}[-b_{t+1}e^{-c_{t+1}((Y_{t}-r)x_{t}+(1+r)W_{t})}]\}\\
# =\max_{{x_t}}\{-b_{t+1}e^{-c_{t+1}(1+r)W_{t}}\mathbb{E}_{Y_{t}}[e^{-c_{t+1}(Y_{t}-r)x_{t}}]\}\\
# =\max_{{x_t}}\{-b_{t+1}e^{-c_{t+1}(1+r)W_{t}}[pe^{-c_{t+1}(a-r)x_{t}}+(1-p)e^{-c_{t+1}(b-r)x_{t}}]\}\\
# \Rightarrow Q^{*}_{t}(W_{t},x_{t})=-b_{t+1}e^{-c_{t+1}(1+r)W_{t}}[pe^{-c_{t+1}(a-r)x_{t}}+(1-p)e^{-c_{t+1}(b-r)x_{t}}]\\
# arg\max_{{x_t}}Q^{*}_{t}(W_{t},x_{t}) \Longleftrightarrow \frac{\partial}{\partial x_t}[pe^{-c_{t+1}(a-r)x_{t}}+(1-p)e^{-c_{t+1}(b-r)x_{t}}]=0\\
# \Rightarrow p(-c_{t+1})(a-r)e^{-c_{t+1}(a-r)x_{t}}+(1-p)(-c_{t+1})(b-r)e^{-c_{t+1}(b-r)x_{t}}=0\\
# \Rightarrow p(a-r)e^{-c_{t+1}(a-r)x_{t}}=(p-1)(b-r)e^{-c_{t+1}(b-r)x_{t}}\\
# \Rightarrow e^{c_{t+1}(a-r)x_{t}-c_{t+1}(b-r)x_{t}}=\frac{p(a-r)}{(p-1)(b-r)}\\
# \Rightarrow c_{t+1}x_t(a-b)=ln\frac{p(a-r)}{(p-1)(b-r)}\\
# \Rightarrow x^*_t=\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{c_{t+1}(a-b)}
# $$
# Note that $$p\in(0,1)$$
# and We require
# $$
# \frac{p(a-r)}{(p-1)(b-r)}>0 \Rightarrow \frac{a-r}{b-r}<0\\
# \Rightarrow r \in(b,a)
# $$
# Also note that
# $$
# \frac{\partial^2}{\partial x^2_t}Q^{*}_{t}(W_{t})\\
# =-b_{t+1}e^{-c_{t+1}(1+r)W_{t}}[p(c^2_{t+1})(a-r)^2e^{c_{t+1}(a-r)x_{t}}+(1-p)(c^2_{t+1})(b-r)^2e^{-c_{t+1}(b-r)x_{t}}]<0
# $$
# So, $x_t$ is ensured to achieve the global maximum

# %% [markdown]
# for $t=T-1$, we maximize the Reward function $\frac{-e^{-\alpha W_{T}}}{\alpha}$, so,
# $$
# V^{*}_{T-1}(W_{T-1})=\max_{{x_{T-1}}}\{\mathbb{E}_{Y_t}[\frac{-e^{-\alpha W_{T}}}{\alpha}]\}\\
# =\max_{{x_{T-1}}}\{\mathbb{E}_{Y_t}[\frac{-e^{-\alpha((Y_{t}-r)x_{t}+(1+r)W_{t})}}{\alpha}]\}\\
# =\max_{{x_{T-1}}}\{\frac{-e^{-\alpha(1+r)W_{t}}}{\alpha}\mathbb{E}_{Y_t}[-e^{-\alpha (Y_{t}-r)x_{t}}]\}
# $$
# Treating $\alpha = c_{t+1}=c_T$, we have,
# $$
# x^*_{T-1}=\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{\alpha(a-b)}
# $$

# %% [markdown]
# substitute $x^*_{T-1}$ into $V^{*}_{T-1}(W_{T-1})$
# $$
# V^{*}_{T-1}(W_{T-1})=\frac{-1}{\alpha}[pe^{(r-a)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}+(1-p)e^{(r-b)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}]e^{-\alpha(1+r)W_{T-1}}\\
# \Rightarrow \begin{cases}
#   b_{T-1} = \frac{1}{\alpha}[pe^{(r-a)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}+(1-p)e^{(r-b)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}]\\
#   c_{T-1} = \alpha(1+r)
# \end{cases}
# $$

# %% [markdown]
# for general $t={0,1,...,T-2}$
# $$
# V^{*}_{t}(W_{t})=-b_{t+1}[pe^{(r-a)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}+(1-p)e^{(r-b)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}]e^{-c_{t+1}(1+r)W_{t}}
# $$
# So,
# $$
# \Rightarrow b_{T-2}=b_{T-1}[pe^{(r-a)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}+(1-p)e^{(r-b)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}]\\
# =\frac{1}{\alpha}[pe^{(r-a)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}+(1-p)e^{(r-b)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}]^2\\
# ...\\
# \Rightarrow b_{t} = \frac{1}{\alpha}[pe^{(r-a)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}+(1-p)e^{(r-b)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}]^{(T-t)}\\
# $$
# and
# $$
# \Rightarrow c_{T-2}=c_{T-1}(1+r)\\
# \Rightarrow c_{T-2}=\alpha(1+r)^2\\
# ...\\
# \Rightarrow c_{t}=\alpha(1+r)^{T-t}
# $$
#
# $$
# \Rightarrow \begin{cases}
#   x^*_{t} = \frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{\alpha(1+r)^{(T-t-1)}(a-b)}\\
#   b_{t} = \frac{1}{\alpha}[pe^{(r-a)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}+(1-p)e^{(r-b)\frac{ln\frac{p(a-r)}{(p-1)(b-r)}}{(a-b)}}]^{(T-t)}\\
#   c_{t}=\alpha(1+r)^{T-t}
# \end{cases}
# $$

# %% [markdown]
# ### Code

# %%
import numpy as np
from scipy.stats import bernoulli, norm
import random
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm.notebook import tnrange

# %%
def Utility_CARA(WT,alpha):
    return (1-np.exp(-alpha*WT))/alpha

def b_multiplier(a,b,p,r):
    ln_fun = np.log((p*(a-r))/((p-1)*(b-r)))
    m1 = p*np.exp((r-a)*ln_fun/(a-b))
    m2 = (1-p)*np.exp((r-b)*ln_fun/(a-b))
    return(m1+m2)

def bt(a,b,p,r,T,t,alpha):
    bmul = b_multiplier(a,b,p,r)
    return(bmul**(T-t)/alpha)

def ct(alpha,r,T,t):
    return(alpha*(1+r)**(T-t))

def xt(a,b,p,r,t,alpha):
    return(np.log((p*(a-r))/((p-1)*(b-r)))/(alpha*(1+r)**(T-t-1)*(a-b)))
    
def Qt(bt1,ct1,Wt,xt):
    C = -bt1*np.exp(-ct1*(1+r)*Wt)
    Ep = p*np.exp(-ct1*(a-r)*xt)
    Eq = (1-p)*np.exp(-ct1*(b-r)*xt)
    return(C*(Ep+Eq))

def Vt(bt,ct,Wt):
    return(-bt*np.exp(-ct*Wt))

def Yt(a,b,p,n=1):
    return bernoulli.rvs(size = n,p = p)*(a-b)+b

def Wt(W0,xt,r,Yt,a,b,p):
    t = len(xt)
    W = np.zeros(t+1)
    W[0] = W0
    for i in range(t):
        W[i+1] = (W[i]-xt[i])*(1+r) + xt[i]*(1+Yt(a,b,p))
    return W

# %%
a = 0.08
b = 0.02
p = 0.6
r = 0.03
T = 10
paths = 10000
alpha = 1

# %%
def printPath(path,alpha,t,T,bt1_10,ct1_10,xt0_9,W0_10):
    print("Sample Path " + str(path))
    for t in range(T):
        print("----------------------------------------------------")
        print("Period " + str(t))
        print("b_"+str(t+1)+" = " + str(bt1_10[t]))
        print("c_"+str(t+1)+" = " + str(ct1_10[t]))
        print("Optimal allocation x_"+str(t)+" = " + str(xt0_9[t]))
        print("Wealth = " + str(W0_10[t,path-1]))
        print("Q function value = " + str(Qt(bt1_10[t],ct1_10[t],W0_10[t,path-1],xt0_9[t])))  
    print("----------------------------------------------------")
    print("Period " + str(T))
    print("Terminal Wealth = " + str(W0_10[T,path-1]))
    print("Utility = " + str(Utility_CARA(W0_10[T,path-1],alpha)))

def Allocation(a,b,p,r,T,alpha,paths):
    t = np.array(range(0,T+1))
    bt0_9 = bt(a,b,p,r,T,t[:-1],alpha)
    bt1_10 = bt(a,b,p,r,T,t[1:],alpha)
    ct0_9 = ct(alpha,r,T,t[:-1])
    ct1_10 = ct(alpha,r,T,t[1:])
    xt0_9 = xt(a,b,p,r,t[:-1],alpha)
    print("xt", xt0_9)
    W0_10 = np.zeros((T+1)*paths).reshape((T+1,paths))
    for _ in tnrange(0,paths):
        W0_10[:,_] = Wt(norm.rvs(loc = 1,scale = 0.1),xt0_9,r,Yt,a,b,p)
    
    path = random.randint(1, paths+1)
    printPath(path,alpha,t,T,bt1_10,ct1_10,xt0_9,W0_10)
    
    plt.plot(W0_10)
    plt.title("risk aversion parameter: " + str(alpha))
    plt.show()

# %%
alpha = 10.0**(np.array(range(0,7))-3)
for alpha_i in alpha:
    print("=============================================================================")
    print("alpha: " + str(alpha_i))
    Allocation(a,b,p,r,T,alpha_i,paths)
# Out:
# =============================================================================
# alpha: 0.001
# xt [25737.58981656 26509.71751105 27305.00903638 28124.15930747
#  28967.8840867  29836.9206093  30732.02822758 31653.98907441
#  32603.60874664 33581.71700904]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Sample Path 3144
# ----------------------------------------------------
# Period 0
# b_1 = 27.78196958146403
# c_1 = 0.001304773183829245
# Optimal allocation x_0 = 25737.589816555097
# Wealth = 1.025109528524983
# Q function value = -18.63157212132861
# ----------------------------------------------------
# Period 1
# b_2 = 41.369307413675315
# c_2 = 0.0012667700813876164
# Optimal allocation x_1 = 26509.71751105175
# Wealth = 1287.9353536421331
# Q function value = -5.175436700369076
# ----------------------------------------------------
# Period 2
# b_3 = 61.60180943503087
# c_3 = 0.0012298738654248703
# Optimal allocation x_2 = 27305.009036383304
# Wealth = 2652.059289803983
# Q function value = -1.4376213056580807
# ----------------------------------------------------
# Period 3
# b_4 = 91.72942847999987
# c_4 = 0.001194052296529
# Optimal allocation x_3 = 28124.159307474805
# Wealth = 2458.5709781342703
# Q function value = -2.995044386787667
# ----------------------------------------------------
# Period 4
# b_5 = 136.591572981986
# c_5 = 0.0011592740743
# Optimal allocation x_4 = 28967.884086699054
# Wealth = 3938.536072852039
# Q function value = -0.8319567741076849
# ----------------------------------------------------
# Period 5
# b_6 = 203.3944625934426
# c_6 = 0.0011255088100000001
# Optimal allocation x_5 = 29836.92060930002
# Wealth = 5505.086359372555
# Q function value = -0.23109910391880054
# ----------------------------------------------------
# Period 6
# b_7 = 302.86866539805646
# c_7 = 0.001092727
# Optimal allocation x_6 = 30732.028227579027
# Wealth = 5371.869744060732
# Q function value = -0.4814564664975019
# ----------------------------------------------------
# Period 7
# b_8 = 450.9927522626529
# c_8 = 0.0010609
# Optimal allocation x_7 = 31653.989074406396
# Wealth = 5225.705554106764
# Q function value = -1.0030343052031279
# ----------------------------------------------------
# Period 8
# b_9 = 671.5599394414863
# c_9 = 0.00103
# Optimal allocation x_8 = 32603.608746638587
# Wealth = 6965.176174450287
# Q function value = -0.27862064033420225
# ----------------------------------------------------
# Period 9
# b_10 = 1000.0
# c_10 = 0.001
# Optimal allocation x_9 = 33581.71700903774
# Wealth = 6848.095372217409
# Q function value = -0.5804596673629216
# ----------------------------------------------------
# Period 10
# Terminal Wealth = 8732.62408383582
# Utility = 999.8387612035103
# =============================================================================
# alpha: 0.01
# xt [2573.75898166 2650.97175111 2730.50090364 2812.41593075 2896.78840867
#  2983.69206093 3073.20282276 3165.39890744 3260.36087466 3358.1717009 ]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Sample Path 6251
# ----------------------------------------------------
# Period 0
# b_1 = 2.778196958146403
# c_1 = 0.01304773183829245
# Optimal allocation x_0 = 2573.7589816555096
# Wealth = 1.2246341690987967
# Q function value = -1.8352708575430656
# ----------------------------------------------------
# Period 1
# b_2 = 4.136930741367531
# c_2 = 0.012667700813876165
# Optimal allocation x_1 = 2650.971751105175
# Wealth = -24.476216622383163
# Q function value = -3.823480953214711
# ----------------------------------------------------
# Period 2
# b_3 = 6.160180943503087
# c_3 = 0.012298738654248702
# Optimal allocation x_2 = 2730.5009036383303
# Wealth = 107.33808443420412
# Q function value = -1.062078042559642
# ----------------------------------------------------
# Period 3
# b_4 = 9.172942847999987
# c_4 = 0.011940522965290001
# Optimal allocation x_3 = 2812.4159307474806
# Wealth = 83.25321793084686
# Q function value = -2.212662588665924
# ----------------------------------------------------
# Period 4
# b_5 = 13.659157298198599
# c_5 = 0.011592740743
# Optimal allocation x_4 = 2896.788408669905
# Wealth = 57.62665516129755
# Q function value = -4.609713726387339
# ----------------------------------------------------
# Period 5
# b_6 = 20.33944625934426
# c_6 = 0.011255088100000001
# Optimal allocation x_5 = 2983.6920609300023
# Wealth = 204.19487524963188
# Q function value = -1.2804760351075921
# ----------------------------------------------------
# Period 6
# b_7 = 30.286866539805644
# c_7 = 0.010927270000000001
# Optimal allocation x_6 = 3073.202822757902
# Wealth = 359.505324553621
# Q function value = -0.3556877875298865
# ----------------------------------------------------
# Period 7
# b_8 = 45.09927522626529
# c_8 = 0.010609
# Optimal allocation x_7 = 3165.3989074406395
# Wealth = 339.55845606265075
# Q function value = -0.741016224020596
# ----------------------------------------------------
# Period 8
# b_9 = 67.15599394414863
# c_9 = 0.0103
# Optimal allocation x_8 = 3260.360874663859
# Wealth = 318.0912206701237
# Q function value = -1.5437838000429118
# ----------------------------------------------------
# Period 9
# b_10 = 100.0
# c_10 = 0.01
# Optimal allocation x_9 = 3358.1717009037748
# Wealth = 295.03034854358884
# Q function value = -3.2162162500893996
# ----------------------------------------------------
# Period 10
# Terminal Wealth = 471.7898440450854
# Utility = 99.10660659719738
# =============================================================================
# alpha: 0.1
# xt [257.37589817 265.09717511 273.05009036 281.24159307 289.67884087
#  298.36920609 307.32028228 316.53989074 326.03608747 335.81717009]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Sample Path 9386
# ----------------------------------------------------
# Period 0
# b_1 = 0.2778196958146403
# c_1 = 0.1304773183829245
# Optimal allocation x_0 = 257.37589816555095
# Wealth = 1.0074293579672715
# Q function value = -0.16294785482200974
# ----------------------------------------------------
# Period 1
# b_2 = 0.41369307413675316
# c_2 = 0.12667700813876165
# Optimal allocation x_1 = 265.0971751105175
# Wealth = 13.90644714698385
# Q function value = -0.04526329300611375
# ----------------------------------------------------
# Period 2
# b_3 = 0.6160180943503087
# c_3 = 0.12298738654248703
# Optimal allocation x_2 = 273.050090363833
# Wealth = 27.57849931691925
# Q function value = -0.0125731369461427
# ----------------------------------------------------
# Period 3
# b_4 = 0.9172942847999987
# c_4 = 0.11940522965290001
# Optimal allocation x_3 = 281.24159307474804
# Wealth = 25.67535339278848
# Q function value = -0.026194035304464038
# ----------------------------------------------------
# Period 4
# b_5 = 1.3659157298198599
# c_5 = 0.11592740743000002
# Optimal allocation x_4 = 289.67884086699047
# Wealth = 40.507693648309555
# Q function value = -0.007276120917906654
# ----------------------------------------------------
# Period 5
# b_6 = 2.033944625934426
# c_6 = 0.11255088100000002
# Optimal allocation x_5 = 298.36920609300023
# Wealth = 56.20686650110838
# Q function value = -0.002021144699418514
# ----------------------------------------------------
# Period 6
# b_7 = 3.0286866539805644
# c_7 = 0.1092727
# Optimal allocation x_6 = 307.32028227579025
# Wealth = 54.9093804352116
# Q function value = -0.0042107181237885875
# ----------------------------------------------------
# Period 7
# b_8 = 4.509927522626529
# c_8 = 0.10609
# Optimal allocation x_7 = 316.53989074406394
# Wealth = 71.9226759620575
# Q function value = -0.0011696439232746036
# ----------------------------------------------------
# Period 8
# b_9 = 6.7155993944148635
# c_9 = 0.10300000000000001
# Optimal allocation x_8 = 326.0360874663858
# Wealth = 70.91495733347858
# Q function value = -0.002436758173488755
# ----------------------------------------------------
# Period 9
# b_10 = 10.0
# c_10 = 0.1
# Optimal allocation x_9 = 335.81717009037743
# Wealth = 69.78204517881909
# Q function value = -0.005076579528101575
# ----------------------------------------------------
# Period 10
# Terminal Wealth = 68.51733483327985
# Utility = 9.989423792649788
# =============================================================================
# alpha: 1.0
# xt [25.73758982 26.50971751 27.30500904 28.12415931 28.96788409 29.83692061
#  30.73202823 31.65398907 32.60360875 33.58171701]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Sample Path 8022
# ----------------------------------------------------
# Period 0
# b_1 = 0.02778196958146403
# c_1 = 1.304773183829245
# Optimal allocation x_0 = 25.737589816555097
# Wealth = 0.8694252171683733
# Q function value = -0.005799666634652727
# ----------------------------------------------------
# Period 1
# b_2 = 0.04136930741367532
# c_2 = 1.2667700813876164
# Optimal allocation x_1 = 26.509717511051754
# Wealth = 0.6381320755178734
# Q function value = -0.012082638822193188
# ----------------------------------------------------
# Period 2
# b_3 = 0.06160180943503087
# c_3 = 1.2298738654248702
# Optimal allocation x_2 = 27.305009036383304
# Wealth = 0.39217886267288904
# Q function value = -0.025172164212902578
# ----------------------------------------------------
# Period 3
# b_4 = 0.09172942847999987
# c_4 = 1.1940522965290001
# Optimal allocation x_3 = 28.124159307474805
# Wealth = 1.769194680372241
# Q function value = -0.006992267836917384
# ----------------------------------------------------
# Period 4
# b_5 = 0.136591572981986
# c_5 = 1.1592740743
# Optimal allocation x_4 = 28.967884086699048
# Wealth = 3.228478486157151
# Q function value = -0.0019422966213659353
# ----------------------------------------------------
# Period 5
# b_6 = 0.2033944625934426
# c_6 = 1.1255088100000001
# Optimal allocation x_5 = 29.836920609300023
# Wealth = 3.0356539998748744
# Q function value = -0.004046451294512371
# ----------------------------------------------------
# Period 6
# b_7 = 0.30286866539805646
# c_7 = 1.092727
# Optimal allocation x_6 = 30.732028227579022
# Wealth = 4.6185696503361235
# Q function value = -0.001124014248475656
# ----------------------------------------------------
# Period 7
# b_8 = 0.4509927522626529
# c_8 = 1.0609
# Optimal allocation x_7 = 31.6539890744064
# Wealth = 4.449806457570418
# Q function value = -0.0023416963509909497
# ----------------------------------------------------
# Period 8
# b_9 = 0.6715599394414864
# c_9 = 1.03
# Optimal allocation x_8 = 32.603608746638585
# Wealth = 4.2667607605534705
# Q function value = -0.004878534064564459
# ----------------------------------------------------
# Period 9
# b_10 = 1.0
# c_10 = 1.0
# Optimal allocation x_9 = 33.581717009037746
# Wealth = 6.024944020702009
# Q function value = -0.0013551483512678987
# ----------------------------------------------------
# Period 10
# Terminal Wealth = 7.884778191774959
# Utility = 0.9996235699024256
# =============================================================================
# alpha: 10.0
# xt [2.57375898 2.65097175 2.7305009  2.81241593 2.89678841 2.98369206
#  3.07320282 3.16539891 3.26036087 3.3581717 ]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Sample Path 9433
# ----------------------------------------------------
# Period 0
# b_1 = 0.002778196958146403
# c_1 = 13.04773183829245
# Optimal allocation x_0 = 2.5737589816555095
# Wealth = 0.8367152745132491
# Q function value = -2.439570449212036e-08
# ----------------------------------------------------
# Period 1
# b_2 = 0.004136930741367532
# c_2 = 12.667700813876163
# Optimal allocation x_1 = 2.650971751105175
# Wealth = 0.990504681831422
# Q function value = -6.77658458114457e-09
# ----------------------------------------------------
# Period 2
# b_3 = 0.006160180943503088
# c_3 = 12.298738654248702
# Optimal allocation x_2 = 2.7305009036383305
# Wealth = 1.1527684098416238
# Q function value = -1.8823846058734825e-09
# ----------------------------------------------------
# Period 3
# b_4 = 0.009172942847999988
# c_4 = 11.94052296529
# Optimal allocation x_3 = 2.812415930747481
# Wealth = 1.3238765073187893
# Q function value = -5.228846127426321e-10
# ----------------------------------------------------
# Period 4
# b_5 = 0.0136591572981986
# c_5 = 11.592740743
# Optimal allocation x_4 = 2.8967884086699054
# Wealth = 1.335468643230878
# Q function value = -1.0893429432138216e-09
# ----------------------------------------------------
# Period 5
# b_6 = 0.02033944625934426
# c_6 = 11.255088100000002
# Optimal allocation x_5 = 2.983692060930002
# Wealth = 1.3465648184411054
# Q function value = -2.2694644650287884e-09
# ----------------------------------------------------
# Period 6
# b_7 = 0.030286866539805647
# c_7 = 10.92727
# Optimal allocation x_6 = 3.0732028227579025
# Wealth = 1.3571248423850386
# Q function value = -4.728050968809988e-09
# ----------------------------------------------------
# Period 7
# b_8 = 0.04509927522626529
# c_8 = 10.609
# Optimal allocation x_7 = 3.1653989074406397
# Wealth = 1.367106559429011
# Q function value = -9.850106185020778e-09
# ----------------------------------------------------
# Period 8
# b_9 = 0.06715599394414865
# c_9 = 10.3
# Optimal allocation x_8 = 3.2603608746638586
# Wealth = 1.3764657671374751
# Q function value = -2.052105455212652e-08
# ----------------------------------------------------
# Period 9
# b_10 = 0.1
# c_10 = 10.0
# Optimal allocation x_9 = 3.3581717009037746
# Wealth = 1.3851561314049607
# Q function value = -4.275219698359701e-08
# ----------------------------------------------------
# Period 10
# Terminal Wealth = 1.393129098338072
# Utility = 0.09999991093292296
# =============================================================================
# alpha: 100.0
# xt [0.2573759  0.26509718 0.27305009 0.28124159 0.28967884 0.29836921
#  0.30732028 0.31653989 0.32603609 0.33581717]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Sample Path 4067
# ----------------------------------------------------
# Period 0
# b_1 = 0.0002778196958146403
# c_1 = 130.4773183829245
# Optimal allocation x_0 = 0.25737589816555095
# Wealth = 1.1005951890643406
# Q function value = -1.0814534534654982e-68
# ----------------------------------------------------
# Period 1
# b_2 = 0.0004136930741367532
# c_2 = 126.67700813876164
# Optimal allocation x_1 = 0.2650971751105175
# Wealth = 1.1310392857546154
# Q function value = -2.2530280280531588e-68
# ----------------------------------------------------
# Period 2
# b_3 = 0.0006160180943503087
# c_3 = 122.98738654248702
# Optimal allocation x_2 = 0.27305009036383304
# Wealth = 1.1623194925761486
# Q function value = -4.693808391777493e-68
# ----------------------------------------------------
# Period 3
# b_4 = 0.0009172942847999987
# c_4 = 119.40522965290002
# Optimal allocation x_3 = 0.28124159307474805
# Wealth = 1.2108415818716247
# Q function value = -1.3038356643826417e-68
# ----------------------------------------------------
# Period 4
# b_5 = 0.0013659157298198598
# c_5 = 115.92740743
# Optimal allocation x_4 = 0.28967884086699053
# Wealth = 1.261228908981511
# Q function value = -3.6217657343962417e-69
# ----------------------------------------------------
# Period 5
# b_6 = 0.002033944625934426
# c_6 = 112.55088100000002
# Optimal allocation x_5 = 0.29836920609300016
# Wealth = 1.313549718294306
# Q function value = -1.0060460373322644e-69
# ----------------------------------------------------
# Period 6
# b_7 = 0.0030286866539805646
# c_7 = 109.2727
# Optimal allocation x_6 = 0.3073202822757902
# Wealth = 1.3678746701477853
# Q function value = -2.7945723259229673e-70
# ----------------------------------------------------
# Period 7
# b_8 = 0.004509927522626529
# c_8 = 106.08999999999999
# Optimal allocation x_7 = 0.31653989074406397
# Wealth = 1.4058377074294612
# Q function value = -5.822025679006112e-70
# ----------------------------------------------------
# Period 8
# b_9 = 0.006715599394414864
# c_9 = 103.0
# Optimal allocation x_8 = 0.3260360874663859
# Wealth = 1.4638398331895484
# Q function value = -1.6172293552794356e-70
# ----------------------------------------------------
# Period 9
# b_10 = 0.01
# c_10 = 100.0
# Optimal allocation x_9 = 0.3358171700903774
# Wealth = 1.504494667310571
# Q function value = -3.369227823498785e-70
# ----------------------------------------------------
# Period 10
# Terminal Wealth = 1.5462713356289846
# Utility = 0.01
# =============================================================================
# alpha: 1000.0
# xt [0.02573759 0.02650972 0.02730501 0.02812416 0.02896788 0.02983692
#  0.03073203 0.03165399 0.03260361 0.03358172]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Sample Path 1019
# ----------------------------------------------------
# Period 0
# b_1 = 2.778196958146403e-05
# c_1 = 1304.773183829245
# Optimal allocation x_0 = 0.025737589816555096
# Wealth = 0.8687248267765475
# Q function value = -0.0
# ----------------------------------------------------
# Period 1
# b_2 = 4.1369307413675316e-05
# c_2 = 1266.7700813876163
# Optimal allocation x_1 = 0.026509717511051755
# Wealth = 0.8945291956816785
# Q function value = -0.0
# ----------------------------------------------------
# Period 2
# b_3 = 6.160180943503088e-05
# c_3 = 1229.8738654248702
# Optimal allocation x_2 = 0.027305009036383304
# Wealth = 0.9226905574276815
# Q function value = -0.0
# ----------------------------------------------------
# Period 3
# b_4 = 9.172942847999987e-05
# c_4 = 1194.0522965290002
# Optimal allocation x_3 = 0.028124159307474805
# Wealth = 0.951736524602331
# Q function value = -0.0
# ----------------------------------------------------
# Period 4
# b_5 = 0.00013659157298198598
# c_5 = 1159.2740743000002
# Optimal allocation x_4 = 0.02896788408669905
# Wealth = 0.9816948283057747
# Q function value = -0.0
# ----------------------------------------------------
# Period 5
# b_6 = 0.0002033944625934426
# c_6 = 1125.50881
# Optimal allocation x_5 = 0.029836920609300027
# Wealth = 1.010855994314081
# Q function value = -0.0
# ----------------------------------------------------
# Period 6
# b_7 = 0.00030286866539805645
# c_7 = 1092.727
# Optimal allocation x_6 = 0.030732028227579023
# Wealth = 1.0408833049374104
# Q function value = -0.0
# ----------------------------------------------------
# Period 7
# b_8 = 0.0004509927522626529
# c_8 = 1060.8999999999999
# Optimal allocation x_7 = 0.0316539890744064
# Wealth = 1.0718024838032572
# Q function value = -0.0
# ----------------------------------------------------
# Period 8
# b_9 = 0.0006715599394414864
# c_9 = 1030.0
# Optimal allocation x_8 = 0.03260360874663859
# Wealth = 1.1055392577710752
# Q function value = -0.0
# ----------------------------------------------------
# Period 9
# b_10 = 0.001
# c_10 = 1000.0
# Optimal allocation x_9 = 0.03358171700903775
# Wealth = 1.1403356159415394
# Q function value = -0.0
# ----------------------------------------------------
# Period 10
# Terminal Wealth = 1.1762247702702375
# Utility = 0.001

# %% [markdown]
# #### checking

# %%
alpha = 1
t = np.array(range(0,T+1))
bt0_9 = bt(a,b,p,r,T,t[:-1],alpha)
bt1_10 = bt(a,b,p,r,T,t[1:],alpha)
ct0_9 = ct(alpha,r,T,t[:-1])
ct1_10 = ct(alpha,r,T,t[1:])
xt0_9 = xt(a,b,p,r,t[:-1],alpha)
W0_10 = Wt(norm.rvs(loc = 1,scale = 0.1),xt0_9,r,Yt,a,b,p)
print(Qt(bt1_10,ct1_10,W0_10[:-1],xt0_9))
print(Vt(bt0_9,ct0_9,W0_10[:-1]))
# Out:
# [-5.02962891e-03 -1.04783936e-02 -2.91066488e-03 -6.06388516e-03
#  -1.68441254e-03 -4.67892373e-04 -1.29970104e-04 -3.61028066e-05
#  -7.52141804e-05 -2.08928279e-05]
# [-5.02962891e-03 -1.04783936e-02 -2.91066488e-03 -6.06388516e-03
#  -1.68441254e-03 -4.67892373e-04 -1.29970104e-04 -3.61028066e-05
#  -7.52141804e-05 -2.08928279e-05]
